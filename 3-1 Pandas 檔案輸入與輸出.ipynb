# %%
# 安裝套件
# !pip install pandas openpyxl

# %%
# 匯入套件
import pandas as pd

# %%
df = pd.read_csv("./files/NPA_TD1.csv", encoding="utf-8"); df
# Out:
#      CityName RegionName       Address   DeptNm BranchNm  Longitude  \
# 0        設置縣市     設置市區鄉鎮          設置地址     管轄警局     管轄分局         經度
# 1         連江縣        南竿鄉    介壽村47-10號前   連江縣警察局    南竿警察所  119.95137
# 2         連江縣        北竿鄉      塘岐村168號前   連江縣警察局    北竿警察所  119.99763
# 3         連江縣        北竿鄉       板里村46號前   連江縣警察局    北竿警察所  119.97415
# 4         金門縣        金城鎮       西海路水頭路段   金門縣警察局     金城分局  118.29999
# ...       ...        ...           ...      ...      ...        ...
# 2221     國道十號        NaN  國道十號東向14.7公里  國道公路警察局  國道公路警五隊   120.3869
# 2222     國道十號        NaN  國道十號西向16.8公里  國道公路警察局  國道公路警五隊  120.40675
# 2223     國道3甲        NaN   國道三甲西向1.7公里  國道公路警察局  國道公路警九隊  121.56336
# 2224     國道3甲        NaN   國道三甲西向3.4公里  國道公路警察局  國道公路警九隊  121.57856
# 2225     台2已線        NaN   台2己線北向1.1公里  國道公路警察局  國道公路警九隊  121.73204
#
#        Latitude      direct limit
# 0            緯度        拍攝方向    速限
# 1     26.160198  順向(往介壽村方向)    30
# 2     26.223022   順向(往機場方向)    30
# ...

# %%
df.to_csv("./output.csv", index=False, encoding="utf-8")

# %%
df = pd.read_json("./files/測速照相機地點.json")
df
# Out:
#              success                                             result
# resource_id     True                              A01010000C-000674-011
# limit           True                                               3000
# total           True                                               2226
# fields          True  [{'type': 'text', 'id': 'CityName'}, {'type': ...
# records         True  [{'CityName': '設置縣市', 'RegionName': '設置市區鄉鎮', ...

# %%
df.to_json("./output.json",indent=4, orient="records", lines=False, force_ascii=False)
df
# Out:
#             sno                       sna   sarea                 mday  \
# 0     500101001        YouBike2.0_捷運科技大樓站     大安區  2024-06-11 15:21:20
# 1     500101002    YouBike2.0_復興南路二段273號前     大安區  2024-06-11 15:25:15
# 2     500101003      YouBike2.0_國北教大實小東側門     大安區  2024-06-11 15:21:20
# 3     500101004         YouBike2.0_和平公園東側     大安區  2024-06-11 15:22:52
# 4     500101005      YouBike2.0_辛亥復興路口西北側     大安區  2024-06-11 15:22:47
# ...         ...                       ...     ...                  ...
# 1414  500119087      YouBike2.0_臺大總圖書館西南側  臺大公館校區  2024-06-11 15:24:19
# 1415  500119088        YouBike2.0_臺大黑森林西側  臺大公館校區  2024-06-11 15:24:19
# 1416  500119089        YouBike2.0_臺大獸醫館南側  臺大公館校區  2024-06-11 15:24:19
# 1417  500119090      YouBike2.0_臺大新體育館東南側  臺大公館校區  2024-06-11 15:25:21
# 1418  500119091  YouBike2.0_臺大明達館北側(員工宿舍)  臺大公館校區  2024-06-11 15:23:19
#
#                  ar     sareaen  \
# 0       復興南路二段235號前  Daan Dist.
# 1      復興南路二段273號西側  Daan Dist.
# ...
